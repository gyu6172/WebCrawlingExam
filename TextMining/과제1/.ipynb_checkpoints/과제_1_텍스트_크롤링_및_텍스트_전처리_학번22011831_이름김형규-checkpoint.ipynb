# %% [markdown]
# # Step 0-1: 라이브러리 설치 및 임포트

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\gyu61\anaconda3\lib\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\gyu61\anaconda3\lib\site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in c:\users\gyu61\anaconda3\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\gyu61\anaconda3\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gyu61\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gyu61\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gyu61\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gyu61\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\gyu61\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gyu61\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gyu61\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\gyu61\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import nltk
import os
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gyu61\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gyu61\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\gyu61\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# # Step 0-2: HTML 구조 탐색 (크롤링 전 분석)

# %% [markdown]
# 🔍 브라우저에서 HTML 구조 직접 확인하기
#
#
# 1️⃣ 브라우저에서 아래 URL 접속
#    👉 https://en.wikipedia.org/wiki/Machine_learning
#
# 2️⃣ 개발자 도구 열기
#    - Windows: F12 또는 Ctrl + Shift + I
#    - Mac: Cmd + Option + I
#
# 3️⃣ Elements 탭에서 본문 텍스트 찾기
#    - 본문 문단 위에서 마우스 우클릭 → "검사" 클릭
#    - 해당 요소의 태그와 상위 구조 확인
#
# 4️⃣ 아래 질문에 답해보세요:
#
#    Q1. 본문 문단은 어떤 태그로 감싸져 있나요?
#
#    Q2. 본문 영역을 감싸는 상위 `<div>`의 id는 무엇인가요?
#
#    Q3. 본문만 정확히 가져오려면 어떤 CSS 선택자를 써야 할까요?

# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/Machine_learning"
headers = {"User-Agent": "Mozilla/5.0"}

res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text, "html.parser")

all_p = soup.find_all("p")  # 👈 여기를 채우세요!
print(f"전체 <p> 태그 개수: {len(all_p)}개")

first_p = soup.find("p")  # 👈 여기를 채우세요!
print(first_p.get_text()[:300])

content_p = soup.select("#mw-content-text")  # 👈 여기를 채우세요!
print(f"본문 <p> 태그 개수: {len(content_p)}개")
print(f"\n첫 번째 문단:\n{content_p[0].get_text()[:300]}")
# Out:
# 전체 <p> 태그 개수: 114개
#
#
# 본문 <p> 태그 개수: 1개
#
# 첫 번째 문단:
#
# Study of algorithms that improve automatically through experience
# For the journal, see Machine Learning (journal).
# "Statistical learning" redirects here. For statistical learning in linguistics, see Statistical learning in language acquisition.
#
#
# Part of a series onMachine learningand data mining
# P

# %% [markdown]
# # Step 1: Wikipedia 100개 문서 크롤링
# ## Step 1-1: Wikipedia 랜덤 제목 100개 수집

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

headers = {
    "User-Agent": "Mozilla/5.0"
}

url = "https://en.wikipedia.org/w/api.php"

# API 파라미터 설정
# 참고: https://www.mediawiki.org/wiki/API:Random
params = {
    "action": "query",
    "format": "json",
    "list": "random",
    "rnnamespace": 0,
    "rnlimit": 100 # 👈 여기를 채우세요!
}

response = requests.get(url, params=params, headers=headers)

data = response.json()

print(data)
# Out:
# {'batchcomplete': '', 'continue': {'rncontinue': '0.478402226583|0.478416660512|1129884|0', 'continue': '-||'}, 'query': {'random': [{'id': 54611803, 'ns': 0, 'title': 'SEK Class Theta-beta'}, {'id': 65716698, 'ns': 0, 'title': 'Kengo Yamazaki'}, {'id': 33566090, 'ns': 0, 'title': 'Winye language'}, {'id': 19035693, 'ns': 0, 'title': 'Jankowce'}, {'id': 37156884, 'ns': 0, 'title': '2012 ARIA Music Awards'}, {'id': 7676976, 'ns': 0, 'title': 'Russett, Maryland'}, {'id': 41148554, 'ns': 0, 'title': 'Wilson Mukama'}, {'id': 23058658, 'ns': 0, 'title': 'Ollie King'}, {'id': 76116295, 'ns': 0, 'title': 'Bichhiya, Madhya Pradesh'}, {'id': 57202800, 'ns': 0, 'title': 'Experimental Psychology (journal)'}, {'id': 61837215, 'ns': 0, 'title': 'Greg Gbur'}, {'id': 1269279, 'ns': 0, 'title': 'Earl Campbell'}, {'id': 11049618, 'ns': 0, 'title': 'David Mack (police officer)'}, {'id': 3252212, 'ns': 0, 'title': 'Voluntary dismissal'}, {'id': 998116, 'ns': 0, 'title': 'Node (networking)'}, {'id': 1820880, 'ns': 0, 'title': 'Skipton and Ripon'}, {'id': 25615230, 'ns': 0, 'title': 'Henry Gale (cricketer)'}, {'id': 2224369, 'ns': 0, 'title': 'Aspern'}, {'id': 19829874, 'ns': 0, 'title': 'Zwola, Garwolin County'}, {'id': 1049478, 'ns': 0, 'title': 'Chapter Music'}, {'id': 9418580, 'ns': 0, 'title': 'Denis Azabagić'}, {'id': 15351171, 'ns': 0, 'title': 'Katonga River'}, {'id': 3456189, 'ns': 0, 'title': 'List of thalamic nuclei'}, {'id': 4366638, 'ns': 0, 'title': 'Peter Howard'}, {'id': 56082554, 'ns': 0, 'title': 'Babak Hodjat'}, {'id': 15763930, 'ns': 0, 'title': 'Mortlach, Saskatchewan'}, {'id': 58808758, 'ns': 0, 'title': 'Orthodox schism'}, {'id': 23579396, 'ns': 0, 'title': 'James Vince'}, {'id': 72552127, 'ns': 0, 'title': 'Aşağıkonak, Cizre'}, {'id': 31530668, 'ns': 0, 'title': 'FC Dinamo Kant'}, {'id': 9505256, 'ns': 0, 'title': 'A Lucky Day'}, {'id': 17255734, 'ns': 0, 'title': 'The Magic Clown'}, {'id': 63556530, 'ns': 0, 'title': 'Surasak Thong-aon'}, {'id': 37531926, 'ns': 0, 'title': 'Al-Qasim ibn Ubayd Allah'}, {'id': 36901603, 'ns': 0, 'title': 'Libzip'}, {'id': 291514, 'ns': 0, 'title': 'Richard Montgomery High School'}, {'id': 63870007, 'ns': 0, 'title': 'Albinia (1813 ship)'}, {'id': 6537440, 'ns': 0, 'title': 'Gravatá'}, {'id': 60009697, 'ns': 0, 'title': 'José Ignacio Iruretagoyena'}, {'id': 53839997, 'ns': 0, 'title': 'Podaná'}, {'id': 30335318, 'ns': 0, 'title': 'Nirbachito Column'}, {'id': 31960669, 'ns': 0, 'title': 'Einar Rosenqvist'}, {'id': 28956186, 'ns': 0, 'title': 'Silver Shell for Best Director'}, {'id': 546219, 'ns': 0, 'title': 'Kiten (program)'}, {'id': 32859539, 'ns': 0, 'title': 'Alwarthirunagari Permual Temple'}, {'id': 36956418, 'ns': 0, 'title': 'Enazakura Tooru'}, {'id': 14001832, 'ns': 0, 'title': 'El Trompillo Airport'}, {'id': 26183455, 'ns': 0, 'title': 'Tsugaruishi Station'}, {'id': 38486789, 'ns': 0, 'title': 'Nishitani'}, {'id': 41853431, 'ns': 0, 'title': 'Bakaldun-e Gholam Shah'}, {'id': 71307432, 'ns': 0, 'title': 'Wincenty Lipski'}, {'id': 59353329, 'ns': 0, 'title': 'Rolf G. Behrents'}, {'id': 61299408, 'ns': 0, 'title': 'Qais Al-Sindy'}, {'id': 45620776, 'ns': 0, 'title': 'Katrín Sigurdardóttir'}, {'id': 56305359, 'ns': 0, 'title': 'Randle Feilden'}, {'id': 43844510, 'ns': 0, 'title': 'Diego Cervero'}, {'id': 2331439, 'ns': 0, 'title': 'Limburg-Hohenlimburg'}, {'id': 19733735, 'ns': 0, 'title': 'Riot Girl'}, {'id': 17390065, 'ns': 0, 'title': 'Pine Brook'}, {'id': 58829644, 'ns': 0, 'title': 'List of countries by potato production'}, {'id': 79232481, 'ns': 0, 'title': 'René Journiac'}, {'id': 11221679, 'ns': 0, 'title': '1698 in piracy'}, {'id': 36832378, 'ns': 0, 'title': "Et vous, tu m'aimes ?"}, {'id': 75398188, 'ns': 0, 'title': 'Chad Aull'}, {'id': 14549124, 'ns': 0, 'title': 'Dark Shell'}, {'id': 6171166, 'ns': 0, 'title': 'Old Clump Mountain'}, {'id': 21406973, 'ns': 0, 'title': 'Żabicko'}, {'id': 12474347, 'ns': 0, 'title': 'Spot-breasted scimitar babbler'}, {'id': 10702390, 'ns': 0, ' ...

# %%
# 위에서 출력한 JSON 구조를 보고, title만 추출하세요
titles = [item["title"] for item in data["query"]["random"]] # 👈 여기를 채우세요!

print("수집된 문서 수:", len(titles))
print("예시 제목:", titles[:5])
# Out:
# 수집된 문서 수: 100
# 예시 제목: ['SEK Class Theta-beta', 'Kengo Yamazaki', 'Winye language', 'Jankowce', '2012 ARIA Music Awards']

# %% [markdown]
# ## Step 1-2: 각 Wikipedia 페이지 본문(content) 크롤링

# %%
texts = []
refs = []

for title in titles:
    page_url = f"https://en.wikipedia.org/wiki/{title.replace(' ', '_')}"
    res = requests.get(page_url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")

    # References 섹션 따로 추출 (decompose 전에!)
    ref_tags = soup.select(".reflist, .references")
    ref_text = " ".join([r.get_text() for r in ref_tags])

    # References 섹션 제거 후 본문 추출
    for tag in ref_tags:
        tag.decompose()

    paragraphs = soup.select("#mw-content-text p")  # 👈 여기를 채우세요!
    main_text = " ".join([p.get_text() for p in paragraphs])

    texts.append(main_text)
    refs.append(ref_text)

# %% [markdown]
# ## Step 1-3: 데이터프레임 생성

# %%
df = pd.DataFrame({
    "title": titles,
    "content": texts,
    "references": refs
})

df.head()
# Out:
#                     title                                            content  \
# 0    SEK Class Theta-beta  \n SEK (Sidirodromoi Ellinikou Kratous, Hellen...
# 1          Kengo Yamazaki  \n Kengo Yamazaki (山﨑 謙吾, Yamazaki Kengo; born...
# 2          Winye language  Winyé, or Kolsi, is a Gur language of Burkina ...
# 3                Jankowce  Jankowce [jaŋˈkɔft͡sɛ] is a village in the adm...
# 4  2012 ARIA Music Awards  \n The 26th Annual Australian Recording Indust...
#
#                                           references
# 0                       \n^ Durrant 1972, p. 52.\n\n
# 1  \n^ "Profile" (in Japanese). TBS. Retrieved 30...
# 2  \n^ Winyé at Ethnologue (18th ed., 2015) (subs...
# 3  \n^ "Główny Urząd Statystyczny" [Central Stati...
# 4  \n^ Public voted category "Single of the Year"...

# %% [markdown]
# ## Step 1-4: 데이터 확인

# %%
print("총 문서 수:", len(df))
print("첫 번째 문서 길이:", len(df["content"][0]))
# Out:
# 총 문서 수: 100
# 첫 번째 문서 길이: 743

# %% [markdown]
# # Step 2: 텍스트 전처리(Cleaning) 목표
# ## Step 2-1: 소문자 변환
# ## Step 2-2: citation 제거
# ## Step 2-3: 특수문자 제거
# ## Step 2-4: 숫자 제거

# %%
import re

def clean_text(text):
    # 소문자 변환
    text = text.lower() # 👈 여기를 채우세요!

    # [edit], [update] 같은 위키 태그 제거  ← 추가
    text = re.sub(r'\[edit\]', ' ', text)
    
    # [1], [2] 같은 citation 제거
    text = re.sub(r'\[\d+\]', ' ', text) # 👈 여기를 채우세요!

    # 특수문자/숫자 제거
    text = re.sub(r'[^a-z\s]', ' ', text) # 👈 여기를 채우세요!

    return text

df["clean_text"] = df["content"].apply(clean_text)
df[["content","clean_text"]].head(3)
# Out:
#                                              content  \
# 0  \n SEK (Sidirodromoi Ellinikou Kratous, Hellen...
# 1  \n Kengo Yamazaki (山﨑 謙吾, Yamazaki Kengo; born...
# 2  Winyé, or Kolsi, is a Gur language of Burkina ...
#
#                                           clean_text
# 0  \n sek  sidirodromoi ellinikou kratous  hellen...
# 1  \n kengo yamazaki         yamazaki kengo  born...
# 2  winy   or kolsi  is a gur language of burkina ...

# %% [markdown]
# # Step 3: Tokenization + Stopwords 제거

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# 영어 불용어 리스트 로드
stop_words = set(stopwords.words("english"))

def tokenize(text):
    # 토큰화
    tokens = word_tokenize(text) # 👈 여기를 채우세요!
    # 불용어 제거 + 길이 2 이하 제거
    tokens = [w for w in tokens if w not in stop_words and len(w) > 2] # 👈 여기를 채우세요!

    return tokens

df["tokens"] = df["clean_text"].apply(tokenize)
df["tokens"].head()
# Out:
# 0    [sek, sidirodromoi, ellinikou, kratous, hellen...
# 1    [kengo, yamazaki, yamazaki, kengo, born, july,...
# 2    [winy, kolsi, gur, language, burkina, faso, sp...
# 3    [jankowce, village, administrative, district, ...
# 4    [annual, australian, recording, industry, asso...
# Name: tokens, dtype: object

# %% [markdown]
# # Step 4: Word Frequency 분석

# %%
from collections import Counter
# 모든 토큰을 하나로 합치기
all_words = sum(df["tokens"], [])
all_words
# Out:
# ['sek',
#  'sidirodromoi',
#  'ellinikou',
#  'kratous',
#  'hellenic',
#  'state',
#  'railways',
#  'class',
#  'class',
#  'thb',
#  'theta',
#  'beta',
#  'class',
#  'two',
#  'steam',
#  'locomotives',
#  'acquired',
#  'first',
#  'world',
#  'war',
#  'originally',
#  'one',
#  'bulgarian',
#  'state',
#  'railways',
#  'series',
#  'four',
#  'cylinder',
#  'compound',
#  'locomotives',
#  'built',
#  'henschel',
#  'sohn',
#  'given',
#  'class',
#  'letters',
#  'sek',
#  'initially',
#  'numbered',
#  'renumbered',
#  'world',
#  'war',
#  'reclaimed',
#  'bulgarians',
#  'renumbered',
#  'end',
#  'surviving',
#  'become',
#  'class',
#  'steam',
#  'locomotive',
#  'related',
#  'article',
#  'stub',
#  'help',
#  'wikipedia',
#  'adding',
#  'missing',
#  'information',
#  'kengo',
#  'yamazaki',
#  'yamazaki',
#  'kengo',
#  'born',
#  'july',
#  'ibaraki',
#  'prefecture',
#  'japanese',
#  'retired',
#  'track',
#  'field',
#  'sprinter',
#  'specialized',
#  'metres',
#  'personal',
#  'best',
#  'event',
#  'seconds',
#  'set',
#  'tokyo',
#  'competed',
#  'metres',
#  'relay',
#  'world',
#  'championships',
#  'biographical',
#  'article',
#  'japanese',
#  'sprinter',
#  'stub',
#  'help',
#  'wikipedia',
#  'adding',
#  'missing',
#  'information',
#  'winy',
#  'kolsi',
#  'gur',
#  'language',
#  'burkina',
#  'faso',
#  'speakers',
#  'largely',
#  'monolingual',
#  'article',
#  'gur',
#  'languages',
#  'stub',
#  'help',
#  'wikipedia',
#  'adding',
#  'missing',
#  'information',
#  'jankowce',
#  'village',
#  'administrative',
#  'district',
#  'gmina',
#  'lesko',
#  'within',
#  'lesko',
#  'county',
#  'subcarpathian',
#  'voivodeship',
#  'south',
#  'eastern',
#  'poland',
#  'lesko',
#  'county',
#  'location',
#  'article',
#  'stub',
#  'help',
#  'wikipedia',
#  'adding',
#  'missing',
#  'information',
#  'annual',
#  'australian',
#  'recording',
#  'industry',
#  'association',
#  'music',
#  'awards',
#  'generally',
#  'known',
#  'aria',
#  'music',
#  'awards',
#  'simply',
#  'arias',
#  'series',
#  'award',
#  'ceremonies',
#  'included',
#  'aria',
#  'artisan',
#  'awards',
#  'aria',
#  'hall',
#  'fame',
#  'awards',
#  'aria',
#  'fine',
#  'arts',
#  'awards',
#  'aria',
#  'awards',
#  'latter',
#  'ceremony',
#  'took',
#  'place',
#  'november',
#  'sydney',
#  'entertainment',
#  'centre',
#  'telecast',
#  'nine',
#  'network',
#  'channel',
#  'final',
#  'nominees',
#  'aria',
#  'award',
#  'categories',
#  'announced',
#  'october',
#  'well',
#  'nominees',
#  'winners',
#  'fine',
#  'arts',
#  'awards',
#  'artisan',
#  'awards',
#  'peer',
#  'judged',
#  'single',
#  'year',
#  'category',
#  'year',
#  'due',
#  'replacing',
#  'song',
#  'year',
#  'although',
#  'album',
#  'year',
#  'category',
#  'returned',
#  'highest',
#  'selling',
#  'single',
#  'album',
#  'categories',
#  'removed',
#  'third',
#  'time',
#  'aria',
#  'awards',
#  'history',
#  'public',
#  'votes',
#  'used',
#  'categories',
#  'song',
#  'year',
#  'best',
#  'australian',
#  'live',
#  'act',
#  'best',
#  'international',
#  'artist',
#  'first',
#  'time',
#  'category',
#  'best',
#  'video',
#  'moved',
#  'artisan',
#  'awards',
#  'nominees',
#  'song',
#  'year',
#  'ten',
#  'highest',
#  'selling',
#  'australian',
#  'single',
#  'releases',
#  'eligibility',
#  'period',
#  'sales',
#  'different',
#  'releases',
#  'artist',
#  'aggregated',
#  'artists',
#  'allowed',
#  'nominated',
#  'even',
#  'one',
#  'song',
#  'top',
#  'ten',
#  'songs',
#  'must',
#  'also',
#  'released',
#  'singles',
#  'eligibility',
#  'period',
#  'nominees',
#  'best',
#  'australian',
#  'live',
#  'act',
#  'selected',
#  'judging',
#  'school',
#  'specifically',
#  'formed',
#  'purpose',
#  'nominees',
#  'best',
#  'video',
#  'selected',
#  'aria',
#  'voting',
#  'academy',
#  'nominee',
#  'pool',
#  'best',
#  'international',
#  'artist',
#  'drawn',
#  'artists',
#  'whose',
#  'recordings',
#  'make',
#  'top',
#  'ten',
#  'highest',
#  'selling',
#  'international',
#  'releases',
#  'based',
#  'album',
#  'related',
#  'single',
#  'sales',
#  'eligibility',
#  'period',
#  'aria',
#  'hall',
#  'fame',
#  'inducted',
#  'yothu',
#  'yindi',
#  'november',
#  'ceremony',
#  'aria',
#  'awards',
#  'indigenous',
#  'music',
#  'group',
#  'northern',
#  'territory',
#  'yothu',
#  'yindi',
#  'inducted',
#  'aria',
#  'hall',
#  'fame',
#  'lead',
#  'singer',
#  'yunupingu',
#  'reflected',
#  'early',
#  'years',
#  'different',
#  'times',
#  'days',
#  'black',
#  'people',
#  'coming',
#  'white',
#  'world',
#  'sceptical',
#  'people',
#  'music',
#  'able',
#  'open',
#  'minds',
#  'aboriginal',
#  'australia',
#  'race',
#  'people',
#  'going',
#  'winners',
#  'listed',
#  'first',
#  'highlighted',
#  'boldface',
#  'winners',
#  'listed',
#  'first',
#  'highlighted',
#  'boldface',
#  'note',
#  'winners',
#  'listed',
#  'first',
#  'highlighted',
#  'boldface',
#  'note',
#  'russett',
#  'unincorporated',
#  'planned',
#  'community',
#  'acres',
#  'within',
#  'maryland',
#  'city',
#  'census',
#  'designated',
#  'place',
#  'far',
#  'western',
#  'anne',
#  'arundel',
#  'county',
#  'maryland',
#  'united',
#  'states',
#  'situated',
#  'park',
#  'like',
#  'setting',
#  'complemented',
#  'miles',
#  'walking',
#  'trails',
#  'acre',
#  'lake',
#  'nature',
#  'preserve',
#  'approximately',
#  'residents',
#  'live',
#  'russett',
#  'divided',
#  'residential',
#  'neighborhoods',
#  'including',
#  'four',
#  'condominium',
#  'communities',
#  'town',
#  'homes',
#  'six',
#  'single',
#  'family',
#  'home',
#  'neighborhoods',
#  'three',
#  'apartment',
#  'rental',
#  'properties',
#  'four',
#  'sites',
#  'pay',
#  'assessments',
#  'russett',
#  'several',
#  'site',
#  'commercial',
#  'properties',
#  'community',
#  'built',
#  'capacity',
#  'units',
#  'russett',
#  'community',
#  'association',
#  'inc',
#  'rca',
#  'homeowners',
#  'association',
#  'hoa',
#  'homeowners',
#  'members',
#  'annual',
#  'hoa',
#  'fees',
#  'paid',
#  'homeowners',
#  'fund',
#  'annual',
#  'million',
#  'budget',
#  'goes',
#  'toward',
#  'maintenance',
#  'playgrounds',
#  'tot',
#  'lot',
#  'tennis',
#  'basketball',
#  'beach',
#  'volleyball',
#  'courts',
#  'four',
#  'pools',
#  'pool',
#  'house',
#  'walking',
#  'trails',
#  'community',
#  'center',
#  'private',
#  'security',
#  'russett',
#  'served',
#  'western',
#  'district',
#  'anne',
#  'arundel',
#  'county',
#  'police',
#  'police',
#  'substation',
#  'miles',
#  'away',
#  'odenton',
#  'opened',
#  'except',
#  'condominiums',
#  'board',
#  'directors',
#  'neighborhood',
#  'committee',
#  'three',
#  'members',
#  'elected',
#  'annual',
#  'rca',
#  'meeting',
#  'three',
#  'elect',
#  'chairperson',
#  'serves',
#  'voting',
#  'member',
#  'representatives',
#  'neighborhoods',
#  'meet',
#  'monthly',
#  'advise',
#  'community',
#  'issues',
#  'voting',
#  'members',
#  'deciding',
#  'changes',
#  'community',
#  'documents',
#  'special',
#  'fee',
#  'assessments',
#  'membership',
#  'board',
#  'directors',
#  'november',
#  'firstservice',
#  'residential',
#  'contracted',
#  'russett',
#  'provide',
#  'property',
#  'management',
#  'services',
#  'community',
#  'russett',
#  'bordered',
#  'little',
#  'patuxent',
#  'river',
#  'acres',
#  'wetlands',
#  'within',
#  'oxbow',
#  'lake',
#  'nature',
#  'preserve',
#  'attracts',
#  'waterfowl',
#  'birds',
#  'nature',
#  'conservancy',
#  'considers',
#  'preserve',
#  'oxbow',
#  'lake',
#  'largest',
#  'naturally',
#  'occurring',
#  'freshwater',
#  'lake',
#  'state',
#  'also',
#  'adjacent',
#  'russett',
#  'along',
#  'southwestern',
#  'borders',
#  'undisturbed',
#  'acre',
#  'land',
#  'parcel',
#  'owned',
#  'anne',
#  'arundel',
#  'county',
#  'board',
#  'education',
#  'within',
#  'russett',
#  'million',
#  'library',
#  'operated',
#  'anne',
#  'arundel',
#  'county',
#  'public',
#  'library',
#  'completed',
#  'maryland',
#  'city',
#  'russett',
#  'branch',
#  'square',
#  'feet',
#  'four',
#  'times',
#  'size',
#  'shuttered',
#  'predecessor',
#  'initial',
#  'collection',
#  'items',
#  'project',
#  'built',
#  'two',
#  'acres',
#  'donated',
#  'developer',
#  'russett',
#  'community',
#  'limited',
#  'partnership',
#  'rclp',
#  'russett',
#  'within',
#  'zip',
#  'code',
#  'falls',
#  'within',
#  'maryland',
#  'state',
#  'senate',
#  'house',
#  'delegates',
#  'district',
#  'community',
#  'also',
#  'lies',
#  'within',
#  'maryland',
#  'congressional',
#  'district',
#  'anne',
#  'arundel',
#  'county',
#  'council',
#  'district',
#  'russett',
#  'faced',
#  'growth',
#  'pressures',
#  'triggered',
#  'base',
#  'realignment',
#  'closure',
#  'process',
#  'known',
#  'brac',
#  'defense',
#  'workers',
#  'expected',
#  'relocate',
#  'nearby',
#  'fort',
#  'meade',
#  'next',
#  'several',
#  'years',
#  'households',
#  'would',
#  'move',
#  'russett',
#  'period',
#  'brac',
#  'according',
#  'state',
#  'projections',
#  'community',
#  'served',
#  'anne',
#  'arundel',
#  'county',
#  'public',
#  'schools',
#  'several',
#  'private',
#  'schools',
#  'wilson',
#  'mukama',
#  'tanzanian',
#  'ccm',
#  'politician',
#  'former',
#  'secretary',
#  'general',
#  'chama',
#  'cha',
#  'mapinduzi',
#  'article',
#  'tanzanian',
#  'politician',
#  'stub',
#  'help',
#  'wikipedia',
#  'adding',
#  'missing',
#  'information',
#  'ollie',
#  'king',
#  'arcade',
#  'skateboard',
#  'racing',
#  'game',
#  'developed',
#  'amusement',
#  'vision',
#  'published',
#  'sega',
#  'xbox',
#  'based',
#  'sega',
#  'chihiro',
#  'hardware',
#  'march',
#  'making',
#  'amusement',
#  'vision',
#  'game',
#  'run',
#  'sega',
#  'nintendo',
#  'based',
#  'hardware',
#  'following',
#  'limited',
#  'location',
#  'tests',
#  'late',
#  'game',
#  'revealed',
#  'tokyo',
#  'jamma',
#  'arcade',
#  'show',
#  'spiritual',
#  'successor',
#  'top',
#  'skater',
#  'created',
#  'team',
#  'developed',
#  'jet',
#  'set',
#  'radio',
#  'despite',
#  'running',
#  'xbox',
#  'based',
#  'chihiro',
#  'never',
#  'ported',
#  'console',
#  'downhill',
#  'racing',
#  'skate',
#  'tournament',
#  'competition',
#  'named',
#  'ollie',
#  'king',
#  'makes',
#  'debut',
#  'tournament',
#  'takes',
#  'place',
#  'hyde',
#  'lombard',
#  'picadilly',
#  'circus',
#  'fushimi',
#  'castle',
#  'fushimi',
#  'inari',
#  'taisha',
#  'six',
#  'challengers',
#  'phillip',
#  'grinner',
#  'jones',
#  'tez',
#  'tanaka',
#  'miguel',
#  'diaz',
#  'didi',
#  'summers',
#  'scott',
#  'ripper',
#  'bullet',
#  'may',
#  'takes',
#  'crowned',
#  'boarding',
#  'best',
#  'ollie',
#  'king',
#  'ollie',
#  'king',
#  'played',
#  'cabinet',
#  'attached',
#  'skateboard',
#  'like',
#  'setup',
#  'made',
#  'mimic',
#  'experience',
#  'riding',
#  'skateboard',
#  'planting',
#  'one',
#  'weight',
#  'back',
#  'foot',
#  'board',
#  'board',
#  'sink',
#  'mimicking',
#  'action',
#  'skateboarder',
#  'squatting',
#  'ready',
#  'core',
#  'control',
#  'board',
#  'performing',
#  'tricks',
#  'going',
#  'hill',
#  'upon',
#  'shifting',
#  'one',
#  'weight',
#  'front',
#  'mimics',
#  'standard',
#  'skateboard',
#  'trick',
#  'known',
#  'ollie',
#  'allowing',
#  'one',
#  'perform',
#  'skateboard',
#  'tricks',
#  'game',
#  'jump',
#  'tilting',
#  'board',
#  'left',
#  'right',
#  'steers',
#  'player',
#  'character',
#  'four',
#  'players',
#  'play',
#  'one',
#  'six',
#  'characters',
#  'picked',
#  'stats',
#  'competing',
#  'series',
#  'downhill',
#  'skateboarding',
#  'races',
#  'goal',
#  'getting',
#  'first',
#  'place',
#  'eight',
#  'contestants',
#  'compete',
#  'three',
#  'locations',
#  'san',
#  'francisco',
#  'london',
#  'kyoto',
#  'difficulty',
#  'rating',
#  'one',
#  'five',
#  'stars',
#  'cabinet',
#  'difficulty',
#  'modes',
#  'altered',
#  'tracks',
#  'slightly',
#  'kids',
#  'mode',
#  'normal',
#  'mode',
#  'expert',
#  'mode',
#  'race',
#  'tracks',
#  'designed',
#  'akin',
#  'another',
#  'sega',
#  'skateboarding',
#  'game',
#  'top',
#  'skater',
#  'checkpoint',
#  'heat',
#  'system',
#  'present',
#  'clear',
#  'portion',
#  'stage',
#  'given',
#  'time',
#  'else',
#  'immediately',
#  'disqualified',
#  'solo',
#  'arcade',
#  'run',
#  'player',
#  'character',
#  'deal',
#  'skater',
#  'gangs',
#  'first',
#  'place',
#  'needed',
#  'allowed',
#  'next',
#  'stage',
#  'ollie',
#  'king',
#  'due',
#  'ollie',
#  'king',
#  'coin',
#  'operated',
#  'arcade',
#  'game',
#  'winning',
#  'losing',
#  'discretion',
#  'arcade',
#  'operator',
#  'settings',
#  'demands',
#  'payment',
#  'continue',
#  'next',
#  'stage',
#  'player',
#  'careful',
#  'wipe',
#  'wipe',
#  'outs',
#  'triggered',
#  'falling',
#  'beyond',
#  'safe',
#  'drop',
#  'distance',
#  'regular',
#  'jump',
#  'crashing',
#  'pillars',
#  'walls',
#  'high',
#  'speeds',
#  'unbalanced',
#  'rail',
#  'grind',
#  'game',
#  'health',
#  'mechanic',
#  'similar',
#  'bounds',
#  'extended',
#  'period',
#  'time',
#  'falling',
#  'course',
#  'competitive',
#  'kart',
#  'racing',
#  'games',
#  'stall',
#  'player',
#  'lose',
#  ...]

# %%
# Counter 사용하여 빈도 계산하기
word_freq = Counter(all_words)
# 상위 20개 단어 출력
word_freq.most_common(20)
# Out:
# [('first', 149),
#  ('also', 118),
#  ('one', 99),
#  ('campbell', 95),
#  ('team', 64),
#  ('year', 63),
#  ('series', 60),
#  ('england', 60),
#  ('school', 59),
#  ('world', 56),
#  ('years', 56),
#  ('new', 55),
#  ('time', 53),
#  ('two', 52),
#  ('football', 52),
#  ('sri', 52),
#  ('university', 51),
#  ('rugby', 51),
#  ('named', 50),
#  ('international', 48)]

# %% [markdown]
# # Step 5: WordCloud 시각화

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(all_words) # 👈 여기를 채우세요!

wordcloud = WordCloud(
    width=800,
    height=400,
    background_color="white"
).generate(text) # 👈 여기를 채우세요!

plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# # Step 6: 데이터 저장

# %%
df.to_csv("wikipedia_text_dataset.csv", index=False)

os.path.exists("wikipedia_text_dataset.csv")
# Out:
# True

# %% [markdown]
# # Step 7: 제공된 PPT 형식에 각 Step 별로 설명하는 내용을 만들어라.
# 1.   각 Step 별 결과물 스크린샷
# 2.   해당 Step에서 해당 코드가 적용되는 본인의 간단한 이유
# 1.   각 Step에 대한 본인만의 분석 결과
